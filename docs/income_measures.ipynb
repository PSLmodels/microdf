# %% [markdown]
# # Income measures
#
# ## Setup

# %%
import numpy as np
import pandas as pd

import taxcalc as tc
import microdf as mdf

# %% [markdown]
# ## Load data
#
# Start with a `DataFrame` with `expanded_income` and the variables in `expanded_income` excluded from `tpc_eci`.

# %%
df = mdf.calc_df(group_vars=['expanded_income', 'wic_ben', 'housing_ben', 
                             'vet_ben', 'mcare_ben', 'mcaid_ben'],
                 metric_vars=['XTOT'])

# %% [markdown]
# Calculate `tpc_eci`.

# %%
df['tpc_eci'] = mdf.tpc_eci(df)

# %%
df.head()
# Out:
#        expanded_income     snap_ben  ssi_ben  XTOT        e02400  \
# RECID
# 1         56671.604435  2670.493781      0.0   1.0  24567.889745
# 2         55452.916535     0.000000      0.0   2.0      0.000000
# 3         43927.829137     0.000000      0.0   2.0  16057.804941
# 4         35639.635313     0.000000      0.0   2.0      0.000000
# 5         85247.723237     0.000000      0.0   2.0      0.000000
#
#           mcare_ben      e02300  housing_ben  tanf_ben    s006  ...  \
# RECID                                                           ...
# 1      14469.708379     0.00000          0.0       0.0  280.60  ...
# 2          0.000000  1250.18631          0.0       0.0  216.81  ...
# 3      14469.708379     0.00000          0.0       0.0  268.85  ...
# 4          0.000000     0.00000          0.0       0.0  224.88  ...
# 5          0.000000     0.00000          0.0       0.0  240.80  ...
#
#        aftertax_income  vet_ben  wic_ben    other_ben  market_income  \
# RECID
# 1         56671.604435      0.0      0.0  6161.950619  -7.275958e-12
# 2         44924.168333      0.0      0.0     0.000000   5.420273e+04
# 3         43927.829137      0.0      0.0  4598.753905   0.000000e+00
# 4         29936.234000      0.0      0.0     0.000000   3.563964e+04
# 5         72320.705333      0.0      0.0     0.000000   8.524772e+04
#
#                bens           tax    s006_m    XTOT_m       tpc_eci
# RECID
# 1      56671.604435      0.000000  0.000281  0.000281  33400.334145
# 2       1250.186310  10528.748202  0.000217  0.000434  55452.916535
# 3      43927.829137      0.000000  0.000269  0.000538  20656.558846
# 4          0.000000   5703.401313  0.000225  0.000450  35639.635313
# 5          0.000000  12927.017904  0.000241  0.000482  85247.723237
#
# [5 rows x 21 columns]
